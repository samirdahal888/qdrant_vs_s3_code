# %%
import boto3

# %%
client = boto3.client("s3vectors")
# Out:
# ---------------------------------------------------------------------------
# NoRegionError                             Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 client = boto3.client('s3vectors')
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/boto3/__init__.py:93, in client(*args, **kwargs)
#      87 def client(*args, **kwargs):
#      88     """
#      89     Create a low-level service client by name using the default session.
#      90
#      91     See :py:meth:`boto3.session.Session.client`.
#      92     """
# ---> 93     return _get_default_session().client(*args, **kwargs)
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/boto3/session.py:337, in Session.client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config, aws_account_id)
#     332 if aws_account_id is None:
#     333     # Remove aws_account_id for arbitrary
#     334     # botocore version mismatches in AWS Lambda.
#     335     del create_client_kwargs['aws_account_id']
# --> 337 return self._session.create_client(
#     338     service_name, **create_client_kwargs
#     339 )
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/botocore/session.py:1031, in Session.create_client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config, aws_account_id)
#    1016 user_agent_creator.set_client_features(get_context().features)
#    1018 client_creator = botocore.client.ClientCreator(
#    1019     loader,
#    1020     endpoint_resolver,
#    (...)   1029     auth_token_resolver=self.get_auth_token,
#    1030 )
# -> 1031 client = client_creator.create_client(
#    1032     service_name=service_name,
#    1033     region_name=region_name,
#    1034     is_secure=use_ssl,
#    1035     endpoint_url=endpoint_url,
#    1036     verify=verify,
#    1037     credentials=credentials,
#    1038     scoped_config=self.get_scoped_config(),
#    1039     client_config=config,
#    1040     api_version=api_version,
#    1041     auth_token=auth_token,
#    1042 )
#    1043 monitor = self._get_internal_component('monitor')
#    1044 if monitor is not None:
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/botocore/client.py:157, in ClientCreator.create_client(self, service_name, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, api_version, client_config, auth_token)
#     153 if token := self._evaluate_client_specific_token(
#     154     service_model.signing_name
#     155 ):
#     156     auth_token = token
# --> 157 client_args = self._get_client_args(
#     158     service_model,
#     159     region_name,
#     160     is_secure,
#     161     endpoint_url,
#     162     verify,
#     163     credentials,
#     164     scoped_config,
#     165     client_config,
#     166     endpoint_bridge,
#     167     auth_token,
#     168     endpoints_ruleset_data,
#     169     partition_data,
#     170 )
#     171 service_client = cls(**client_args)
#     172 self._register_retries(service_client)
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/botocore/client.py:557, in ClientCreator._get_client_args(self, service_model, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, client_config, endpoint_bridge, auth_token, endpoints_ruleset_data, partition_data)
#     533 def _get_client_args(
#     534     self,
#     535     service_model,
#    (...)    546     partition_data,
#     547 ):
#     548     args_creator = ClientArgsCreator(
#     549         self._event_emitter,
#     550         self._user_agent,
#    (...)    555         user_agent_creator=self._user_agent_creator,
#     556     )
# --> 557     return args_creator.get_client_args(
#     558         service_model,
#     559         region_name,
#     560         is_secure,
#     561         endpoint_url,
#     562         verify,
#     563         credentials,
#     564         scoped_config,
#     565         client_config,
#     566         endpoint_bridge,
#     567         auth_token,
#     568         endpoints_ruleset_data,
#     569         partition_data,
#     570     )
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/botocore/args.py:121, in ClientArgsCreator.get_client_args(self, service_model, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, client_config, endpoint_bridge, auth_token, endpoints_ruleset_data, partition_data)
#     106 def get_client_args(
#     107     self,
#     108     service_model,
#    (...)    119     partition_data=None,
#     120 ):
# --> 121     final_args = self.compute_client_args(
#     122         service_model,
#     123         client_config,
#     124         endpoint_bridge,
#     125         region_name,
#     126         endpoint_url,
#     127         is_secure,
#     128         scoped_config,
#     129     )
#     131     service_name = final_args['service_name']  # noqa
#     132     parameter_validation = final_args['parameter_validation']
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/botocore/args.py:259, in ClientArgsCreator.compute_client_args(self, service_model, client_config, endpoint_bridge, region_name, endpoint_url, is_secure, scoped_config)
#     256 if configured_endpoint_url is not None:
#     257     register_feature_id('ENDPOINT_OVERRIDE')
# --> 259 endpoint_config = self._compute_endpoint_config(
#     260     service_name=service_name,
#     261     region_name=region_name,
#     262     endpoint_url=configured_endpoint_url,
#     263     is_secure=is_secure,
#     264     endpoint_bridge=endpoint_bridge,
#     265     s3_config=s3_config,
#     266 )
#     267 endpoint_variant_tags = endpoint_config['metadata'].get('tags', [])
#     269 # Some third-party libraries expect the final user-agent string in
#     270 # ``client.meta.config.user_agent``. To maintain backwards
#     271 # compatibility, the preliminary user-agent string (before any Config
#     272 # object modifications and without request-specific user-agent
#     273 # components) is stored in the new Config object's ``user_agent``
#     274 # property but not used by Botocore itself.
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/botocore/args.py:447, in ClientArgsCreator._compute_endpoint_config(self, service_name, region_name, endpoint_url, is_secure, endpoint_bridge, s3_config)
#     445 if service_name == 'sts':
#     446     return self._compute_sts_endpoint_config(**resolve_endpoint_kwargs)
# --> 447 return self._resolve_endpoint(**resolve_endpoint_kwargs)
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/botocore/args.py:552, in ClientArgsCreator._resolve_endpoint(self, service_name, region_name, endpoint_url, is_secure, endpoint_bridge)
#     544 def _resolve_endpoint(
#     545     self,
#     546     service_name,
#    (...)    550     endpoint_bridge,
#     551 ):
# --> 552     return endpoint_bridge.resolve(
#     553         service_name, region_name, endpoint_url, is_secure
#     554     )
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/botocore/client.py:671, in ClientEndpointBridge.resolve(self, service_name, region_name, endpoint_url, is_secure)
#     665 use_dualstack_endpoint = self._resolve_use_dualstack_endpoint(
#     666     service_name
#     667 )
#     668 use_fips_endpoint = self._resolve_endpoint_variant_config_var(
#     669     'use_fips_endpoint'
#     670 )
# --> 671 resolved = self.endpoint_resolver.construct_endpoint(
#     672     service_name,
#     673     region_name,
#     674     use_dualstack_endpoint=use_dualstack_endpoint,
#     675     use_fips_endpoint=use_fips_endpoint,
#     676 )
#     678 # If we can't resolve the region, we'll attempt to get a global
#     679 # endpoint for non-regionalized services (iam, route53, etc)
#     680 if not resolved:
#     681     # TODO: fallback partition_name should be configurable in the
#     682     # future for users to define as needed.
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/botocore/regions.py:233, in EndpointResolver.construct_endpoint(self, service_name, region_name, partition_name, use_dualstack_endpoint, use_fips_endpoint)
#     228 if use_dualstack_endpoint and (
#     229     partition['partition']
#     230     in self._UNSUPPORTED_DUALSTACK_PARTITIONS
#     231 ):
#     232     continue
# --> 233 result = self._endpoint_for_partition(
#     234     partition,
#     235     service_name,
#     236     region_name,
#     237     use_dualstack_endpoint,
#     238     use_fips_endpoint,
#     239 )
#     240 if result:
#     241     return result
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/botocore/regions.py:281, in EndpointResolver._endpoint_for_partition(self, partition, service_name, region_name, use_dualstack_endpoint, use_fips_endpoint, force_partition)
#     279         region_name = service_data['partitionEndpoint']
#     280     else:
# --> 281         raise NoRegionError()
#     283 resolve_kwargs = {
#     284     'partition': partition,
#     285     'service_name': service_name,
#    (...)    289     'use_fips_endpoint': use_fips_endpoint,
#     290 }
#     292 # Attempt to resolve the exact region for this partition.
#
# NoRegionError: You must specify a region.

# %%
import time

from dotenv import load_dotenv

from core.config import (
    AWS_REGION,
    EMBEDDING_DIM,
    QDRANT_COLLECTION,
    QDRANT_URL,
    S3V_BUCKET_NAME,
    S3V_INDEX_NAME,
    qdrant_id,
)

# %%
import boto3

client = boto3.client("s3vectors", region_name=AWS_REGION)

try:
    client.create_vector_bucket(vectorBucketName=S3V_BUCKET_NAME)
except client.exceptions.ConflictException:
    pass
try:
    client.create_index(
        vectorBucketName=S3V_BUCKET_NAME,
        indexName=S3V_INDEX_NAME,
        dimension=EMBEDDING_DIM,
        distanceMetric="cosine",
        dataType="float32",
        metadataConfiguration={"nonFilterableMetadataKeys": ["description"]},
    )
except client.exceptions.ConflictException:
    pass

# %%
client.delete_index(
    vectorBucketName=S3V_BUCKET_NAME,
    indexName=S3V_INDEX_NAME,
)
# Out:
# {'ResponseMetadata': {'RequestId': '2b9e5bc7-fb11-4f91-bed5-227912aaf718',
#   'HostId': '',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Sat, 21 Feb 2026 14:49:31 GMT',
#    'content-type': 'application/json',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-amz-request-id': '2b9e5bc7-fb11-4f91-bed5-227912aaf718',
#    'access-control-allow-origin': '*',
#    'vary': 'origin, access-control-request-method, access-control-request-headers',
#    'access-control-expose-headers': '*'},
#   'RetryAttempts': 0}}

# %%
response  = client.get_vectors(
        vectorBucketName=S3V_BUCKET_NAME,
        indexName=S3V_INDEX_NAME,

)
# Out:
# ---------------------------------------------------------------------------
# ParamValidationError                      Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 response  = client.get_vectors(
#       2         vectorBucketName=S3V_BUCKET_NAME,
#       3         indexName=S3V_INDEX_NAME,
#       4
#       5 )
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/botocore/client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     598     raise TypeError(
#     599         f"{py_operation_name}() only accepts keyword arguments."
#     600     )
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/botocore/client.py:1035, in BaseClient._make_api_call(self, operation_name, api_params)
#    1031 if properties:
#    1032     # Pass arbitrary endpoint info with the Request
#    1033     # for use during construction.
#    1034     request_context['endpoint_properties'] = properties
# -> 1035 request_dict = self._convert_to_request_dict(
#    1036     api_params=api_params,
#    1037     operation_model=operation_model,
#    1038     endpoint_url=endpoint_url,
#    1039     context=request_context,
#    1040     headers=additional_headers,
#    1041 )
#    1042 resolve_checksum_context(request_dict, operation_model, api_params)
#    1044 service_id = self._service_model.service_id.hyphenize()
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/botocore/client.py:1102, in BaseClient._convert_to_request_dict(self, api_params, operation_model, endpoint_url, context, headers, set_user_agent_header)
#    1093 def _convert_to_request_dict(
#    1094     self,
#    1095     api_params,
#    (...)   1100     set_user_agent_header=True,
#    1101 ):
# -> 1102     request_dict = self._serializer.serialize_to_request(
#    1103         api_params, operation_model
#    1104     )
#    1105     if not self._client_config.inject_host_prefix:
#    1106         request_dict.pop('host_prefix', None)
#
# File ~/s3_vs_qdrant/.venv/lib/python3.11/site-packages/botocore/validate.py:424, in ParamValidationDecorator.serialize_to_request(self, parameters, operation_model)
#     420     report = self._param_validator.validate(
#     421         parameters, operation_model.input_shape
#     422     )
#     423     if report.has_errors():
# --> 424         raise ParamValidationError(report=report.generate_report())
#     425 return self._serializer.serialize_to_request(
#     426     parameters, operation_model
#     427 )
#
# ParamValidationError: Parameter validation failed:
# Missing required parameter in input: "keys"
